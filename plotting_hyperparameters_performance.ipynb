# %%
import pandas as pd

# %% [markdown]
# # $$t_0$$

# %%
# !ls
# Out:
# drive  sample_data

# %%
df = pd.read_csv('./results/results_t0_metrics.csv')

# %%
df
# Out:
#    t0  accuracy    recall  precision
# 0   5  0.834457  0.836514   0.835883
# 1  10  0.834623  0.836692   0.836144
# 2  15  0.834681  0.836842   0.836106
# 3  20  0.833498  0.835557   0.834958
# 4  25  0.832830  0.834785   0.834342
# 5  30  0.833723  0.835644   0.835248
# 6  35  0.834761  0.836787   0.836305
# 7  40  0.833204  0.835292   0.834537
# 8  45  0.833279  0.835398   0.834689
# 9  50  0.832759  0.834944   0.834149

# %%
df.plot.line('t0', xticks=range(5,55,5), grid=True)

# %% [markdown]
# # Radius

# %%
df = pd.read_csv('./results/results_radius_metrics.csv')

# %%
df
# Out:
#    radius  accuracy    recall  precision
# 0       2  0.854815  0.856475   0.856719
# 1       3  0.841093  0.842783   0.842865
# 2       4  0.834932  0.837086   0.836301
# 3       5  0.835252  0.837397   0.836614
# 4       6  0.836637  0.838905   0.838160
# 5       7  0.834332  0.836632   0.836309
# 6       8  0.836262  0.838649   0.838073

# %%
df.plot.line('radius', xticks=range(2,9), grid=True)
